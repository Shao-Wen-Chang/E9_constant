# %% [markdown]
# `f_` is the intended order to go through the notebooks if I forgot what I did in the future.

# %%
import sys
from pathlib import Path
E9path = Path("C:/", "Users", "ken92", "Documents", "Studies", "E5", "simulation", "E9_simulations")
if str(E9path) not in sys.path:
    sys.path.insert(1, str(E9path))
from E9_fn import util

inverter_path = Path(r"C:\Users\ken92\Documents\Studies\E5\simulation\E9_simulations\projects\flat_band_cooling\tenpy_results")
if str(inverter_path) not in sys.path:
    sys.path.insert(1, str(inverter_path))
from matching_results_inverters import util_thm
import pickle
import matplotlib.pyplot as plt
import numpy as np
from pathlib import Path
import pandas as pd
import os
# Out:
# c:\Users\ken92\Documents\Studies\E5\simulation\E9_simulations\.venv\Lib\site-packages\gftool\precision.py:16: UserWarning: No quad precision datatypes available!
# Some functions might be less accurate.
#   warnings.warn("No quad precision datatypes available!\n"

# %% [markdown]
# # Constant $N_{tot}$ and $S_{tot}$
# Now I have a three-dimensional parameter space $(n_s, N_{tot}, S_{tot})$ for each interaction strength $V$. At each point in this parameter space, I can evaluate things like $s_s$, $V_{offset}$ and so on, possibly with interpolation. A constant $N_{tot}$ and $S_{tot}$ slice gives these parameters as a function of $n_s$ only.
#
# It should be possible to invert $n_s$ and $V_{offset}$ if one wants to, and we know that this has to be a monotonic function. We can do this inversion after the constant $N, S$ slice.
#
# ## Reading data
# Read all the files with the correct parameters to get all $n_s$. This is the slowest step.

# %%
V_input_list = np.array([-0.1, 0, 0.1, 0.3, 1., 3.])
shift = -2.0
tp = 1.41421356237
L_subregion = 50

# %%
N_sites = 2 * L_subregion

# %%
all_ns_df_lists = []    # All the raw data loaded
for i_V, V in enumerate(V_input_list):
    folder_name = f"ST_SL_I_L{L_subregion}_t1_tpsqrt2_shf{int(shift)}_V{V}_chi64"
    if np.isclose(V, 0): folder_name = f"sawtooth_tp{tp}_shift{shift}_spinless_NI_L{L_subregion}"
    folder_path = Path(r"C:\Users\ken92\Downloads\Shao-Wen Data\invert_S_results",
                    folder_name)
    assert folder_path.exists()
    all_ns_df_lists.append([pd.read_csv(csv_path) for csv_path in folder_path.glob("ns*.csv")])

# %% [markdown]
# ## Filtering data
# Only take the point with the desired $N_{tot}$ and $S_{tot}$ from each file.

# %%
thesis_fig_path = Path(r"C:\Users\ken92\Documents\Studies\E5\Theses\figures\flatband")
thesis_fig_path_app = Path(r"C:\Users\ken92\Documents\Studies\E5\Theses\figures\flatband_app")
str_Scase = "smallS"
# str_Scase = "bigS"
# str_Scase = "hugeS"
str_Ncase = "smallN"
# str_Ncase = "bigN"
allow_neg_beta = False
allow_neg_beta = True
bool_for_thesis = True  # set to false if I want to check how the thesis plots look like for other parameters
# bool_for_thesis = False
bool_save_fig = True
bool_save_fig = True
Stot = 65 # = m * 0.2 * (L_subregion / 25), m integer
Ntot = 90

# %%
str_S_title = "low entropy"
ax_S_leg_loc = "lower right"
if bool_for_thesis:
    if str_Ncase == "smallN":
        Ntot = 90
        n_s_start = 0.05
        n_s_stop = 0.88
        if str_Scase == "smallS":
            Stot = 30
        elif str_Scase == "bigS":
            Stot = 36
            str_S_title = "high entropy"
        elif str_Scase == "hugeS":
            Stot = 52 # 66 just enough to see some heating when flat band is half filled; 68 already no cooling anywhere
            str_S_title = "very high entropy"
    elif str_Ncase == "bigN":
        Ntot = 130
        n_s_start = 0.3
        n_s_stop = 0.95
        ax_S_leg_loc = "upper left"
        if str_Scase == "smallS":
            Stot = 52
        elif str_Scase == "bigS":
            Stot = 62
            str_S_title = "high entropy"
        elif str_Scase == "hugeS":
            Stot = 72
            str_S_title = "very high entropy"

str_query = f"Stot == {Stot} & Ntot == {Ntot}"
# Don't use! Also filters out all the runs with nan values and messes up the plots at low Stot
# str_query = f"Stot == {Stot} & Ntot == {Ntot} & beta >= 0"

# %%
ntot = Ntot / 2 / N_sites   # average filling in the joint system
n_s_halfnr = 2 * ntot - 0.75
if n_s_halfnr < 0: n_s_halfnr = np.nan
sigma2tot = Stot / Ntot     # average entropy per particle in the joint system

# %% [markdown]
# Figure out if there are some interaction strengths with no solutions at all.

# %%
df_invert_list = []
good_list = []
for i_V, (V, df_list) in enumerate(zip(V_input_list, all_ns_df_lists)):
    df_record = []
    for df_ns in df_list:
        df_filtered = df_ns.query(str_query)
        if len(df_filtered) > 0:
            df_record.append(df_filtered)
    if len(df_record) == 0:
        continue
    else:
        df_invert_list.append(pd.concat(df_record))
        good_list.append(i_V)

if len(good_list) == 0: raise(Exception("No matching results found"))
V_list = V_input_list[good_list]    # list of V values with at least one matching data point
print(f"good_list = {good_list}")
# Out:
# good_list = [0, 1, 2, 3, 4, 5]

# %% [markdown]
# ### Dump data into arrays

# %%
beta_allV = []
n_s_allV = []
mu_glob_allV = []
V_offset_allV = []
s2_s_allV = []
s2_r_allV = []
sigma2_s_allV = []
sigma2_r_allV = []
varsigma_allV = []
for df_invert in df_invert_list:
    beta_allV.append(df_invert["beta"].to_numpy(dtype=float))
    n_s_allV.append(df_invert["n_s"].to_numpy(dtype=float))
    mu_glob_allV.append(df_invert["mu_glob"].to_numpy(dtype=float))
    V_offset_allV.append(df_invert["V_offset"].to_numpy(dtype=float))
    s2_s_allV.append(df_invert["s2_s"].to_numpy(dtype=float))
    s2_r_allV.append(df_invert["s2_r"].to_numpy(dtype=float))
    sigma2_s_allV.append(df_invert["sigma2_s"].to_numpy(dtype=float))
    sigma2_r_allV.append(df_invert["sigma2_r"].to_numpy(dtype=float))
    varsigma_allV.append(df_invert["varsigma"].to_numpy(dtype=float))
n_f_r_allV = [util.fermi_stat(0, 1 / beta, mu) for (beta, mu) in zip(beta_allV, mu_glob_allV)]# flat band filling (only strictly true for the non-interacting case)

# %% [markdown]
# ### Handle negative beta

# %%
if not allow_neg_beta:
    for i, betas in enumerate(beta_allV):
        idx_dump = betas < 0
        for datas in [beta_allV, n_s_allV, mu_glob_allV, V_offset_allV, s2_s_allV, s2_r_allV, sigma2_s_allV, sigma2_r_allV, varsigma_allV]:
            datas[i][idx_dump] = np.nan

# %% [markdown]
# ## Some post processing
# ### Flat band peculiarities
# The flat band must have enough entropy capacity for $\beta$ to go to infinity, at which the total entropy is explicitly given by
#
# $S_{tot}^\circ \equiv S_{tot}|_{\beta = \infty} =
#  L \sum_{x = r, s} [-(1 - n_{x,f}) \ln(1 - n_{x,f}) - n_{x,f} \ln n_{x,f}]$
#
# where
#
# $n_{x, f} = \max(2 n_{x,r} - 1, 0)$
#
# is the filling in flat band in the system / reservoir. So things are actually rather fine tuned.

# %%
def S_flat(n, L):
    n_f = np.maximum(0., 2 * n - 1.)     # density in the flat band at T = 0
    S = -L * ((1 - n_f) * np.log(1 - n_f) + n_f * np.log(n_f))
    return np.where(np.isnan(S), 0., S)

# %% [markdown]
# For the case of fixed $N_{tot}$ we look at here, $S_{tot}^\circ$ is only a function of $n_s$.

# %%
def S_zeroT(n_s, L, Ntot):
    n = Ntot / 4 / L
    n_r = 2 * n - n_s
    return S_flat(n_s, L) + S_flat(n_r, L)

# %%
n_s_all = np.linspace(0.05, 0.95, 401)
n_r_all = (2 * ntot - n_s_all)
S_zeroT_all = S_zeroT(n_s_all, L_subregion, Ntot)
S_excess = np.maximum(S_zeroT_all - Stot, 0.)

fig_S, (ax_S, ax_S_excess) = plt.subplots(2, 1, height_ratios = (7, 1))
ax_S.plot(n_s_all, S_flat(n_s_all, L_subregion), ls = "--", label = r"$n_s$")
ax_S.plot(n_s_all, S_flat(n_r_all, L_subregion), ls = "--", label = r"$n_r$")
ax_S.plot(n_s_all, S_zeroT_all, alpha = 0.7, label = "sum")
ax_S.plot(n_s_all, np.full_like(n_s_all, Stot), ls = ":", color = "k", label = r"$S_{tot}$")
ax_S.axvline(n_s_halfnr, color = "r", ls = "--", label = r"$n_{r,f} = 1/2$")
ax_S.set_xticks([])
ax_S.set_ylabel(r"$S_{tot}^\circ$")
ryax = ax_S.secondary_yaxis('right', functions = (lambda x: x / Ntot, lambda x: x * Ntot))
ryax.set_ylabel(r"$\sigma$")
ax_S.legend()
util.add_shades(ax_S, S_excess / np.max(S_excess), n_s_all, alpha = 0.5, color = "pink")

ax_S_excess.plot(n_s_all, S_excess)
ax_S_excess.axvline(n_s_halfnr, color = "r", ls = "--")
ax_S_excess.set_xlabel(r"$n_s$")
ax_S_excess.set_ylabel(r"$S_{tot}^\circ - S_{tot}$")
ryax = ax_S_excess.secondary_xaxis('top', functions = (lambda x: 2 * ntot - x, lambda x: 2 * ntot - x))
ryax.set_xlabel(r"$n_r$")

fig_S.suptitle(rf"Entropy at T = 0 ($N_{{tot}} = {Ntot}$, $S_{{tot}} = {Stot}$; $n = {ntot}$, $\sigma = {sigma2tot:.4f}$)")
fig_S.tight_layout()
if bool_for_thesis and bool_save_fig:
    s_circ_path = Path(thesis_fig_path, f"S_circ_{str_Scase}_{str_Ncase}.pdf")
    # fig_S.savefig(s_circ_path, facecolor = "none", dpi = 300)
# Out:
# C:\Users\ken92\AppData\Local\Temp\ipykernel_20340\3817173227.py:3: RuntimeWarning: divide by zero encountered in log
#   S = -L * ((1 - n_f) * np.log(1 - n_f) + n_f * np.log(n_f))
# C:\Users\ken92\AppData\Local\Temp\ipykernel_20340\3817173227.py:3: RuntimeWarning: invalid value encountered in multiply
#   S = -L * ((1 - n_f) * np.log(1 - n_f) + n_f * np.log(n_f))

# %% [markdown]
# ### Finding the minimum $s_s$
# We ask: if we don't ask for a specific $n_s$, what is the $V_{offset}$ that gives us the lowest $s_s$?
#
# It turns out that this is sometimes achieved at very large $n_s$, which is a boring case, because it is just close to a band insulator. Therefore I put an upper limit on $n_s$ .

# %%
argmin_sigma2_s_allV = []
for s2_s, n_s in zip(sigma2_s_allV, n_s_allV):
    if np.all(np.isnan(s2_s)):
        argmin_sigma2_s_allV.append(np.array(0))
        continue
    argmin_sigma2_s_allV.append(np.nanargmin(s2_s[n_s < 0.7]))

# %% [markdown]
# ## Plots
# Some sanity checks that should apply to both plots below:
# * $\varsigma$ should be 0 at $V_{offset} = 0$.
# * $\sigma_s$ and $\sigma_r$ plots should be each other's reflections.
# * The grey line (average entropy per particle in the system) should be at $V_{offset} = 0$, and all the lines should converge there.
# * $\beta$ should be symmetric about the black line.
#     * I think I sometimes get a slight asymmetry due to how finely I can sample $n_s$.
# * $n_s$ should be a monotonically decreasing function of $V_{offset}$ (at least where $\beta > 0$; for $\beta < 0$ the opposite is true).
# ### Handle $\beta$ sign change
# I will add a point with value `np.nan` in between sign changes.

# %%
idx_sgn_change_allV = [util.find_sign_change(beta) for beta in beta_allV]

# %% [markdown]
# ### as $f(n_s)$
# This is what I get directly from my algorithm.
# `np.nan` values are automatically handled by plot() (i.e. plotted as disconnected lines where there are `np.nan` entries).

# %% [markdown]
# #### just $\varsigma$ and just $\beta$
# For the main chapter.

# %%
nmin, nmax = n_s_start, n_s_stop
n_s_all = np.linspace(nmin, nmax, 401)
n_r_all = (2 * ntot - n_s_all)
S_zeroT_all = S_zeroT(n_s_all, L_subregion, Ntot)
S_excess = np.maximum(S_zeroT_all - Stot, 0.)

fig_main, (ax_S, ax_ns_vs, ax_ns_beta) = plt.subplots(3, 1, figsize = (5, 9),)# height_ratios = (7, 1))
ax_S.plot(n_s_all, S_flat(n_s_all, L_subregion), ls = "--", lw = 3, label = r"$n_s$", color = "#156082")
ax_S.plot(n_s_all, S_flat(n_r_all, L_subregion), ls = "--", lw = 3, label = r"$n_r$", color = "#c04f15")
ax_S.plot(n_s_all, S_zeroT_all, lw = 1.5, label = "sum", color = "black")
ax_S.plot(n_s_all, np.full_like(n_s_all, Stot), ls = ":", color = "k", label = r"$S_{tot}$")
ax_S.axvline(n_s_halfnr, color = "r", ls = "--", label = r"$n_{r,f} = 1/2 (T = 0)$")
ax_S.set_xticks([])
ax_S.set_xlim(nmin - 0.01, nmax + 0.01)
ax_S.set_ylabel(r"$S_{tot}^\circ$")
txax = ax_S.secondary_xaxis('top', functions = (lambda x: 2 * ntot - x, lambda x: 2 * ntot - x))
txax.tick_params(labelsize = 10, tickdir = "in")
txax.set_xlabel(r"$n_r$", loc = "right", labelpad = -10, fontsize = 12)
ax_S.legend(fontsize = "small", loc = ax_S_leg_loc)
util.add_shades(ax_S, S_excess / np.max(S_excess), n_s_all, alpha = 0.5, color = "pink")

ax_S.set_title(rf"Entropy at T = 0 ($n = {ntot}$, {str_S_title})")

for ax, vals_allV, str_label in zip([ax_ns_vs, ax_ns_beta], [varsigma_allV, beta_allV], [r"$\varsigma$", r"$\beta$"]):
    util.add_shades(ax, S_excess / np.max(S_excess), n_s_all, alpha = 0.5, color = "pink")
    for n_s, vals, V, i_min, idx_sgn_change in zip(n_s_allV, vals_allV, V_list, argmin_sigma2_s_allV, idx_sgn_change_allV):
        c = util.get_color(V, V_list, crange = (0.15, 0.95))
        if V == 0: c = "orange"
        util.plot_in_ax_break_sign_change(ax, n_s, vals, idx_sgn_change, color = c, label = f"V = {V}")
        ax.scatter(n_s[i_min], vals[i_min], color = c)
    ax.set_title(str_label, fontsize = 16)
    ax.axvline(n_s_halfnr, color = "r", ls = "--", label = r"$n_{r,f} = 1/2 (T = 0)$")
    ax.axvline(ntot, color = "k", ls = "--", label = r"$V_{offset} = 0$")
    ax.tick_params(labelsize = 10, tickdir = "in")
ax_ns_vs.set_xlim(nmin - 0.01, nmax + 0.01)
ax_ns_beta.set_xlim(nmin - 0.01, nmax + 0.01)
ax_ns_vs.set_xticks([])
ax_ns_beta.set_xlabel(r"$n_s$", loc = "right", labelpad = -10, fontsize = 10)

# Fine tunings for each params
if str_Ncase == "bigN": ax_ns_vs.set_yticks([-1, 0, 1, 2])

fig_main.tight_layout()
handles_ns, labels_ns = ax_ns_vs.get_legend_handles_labels()

fig_legend, ax_legend = plt.subplots(figsize=(2, 1))
ax_legend.axis('off')
fig_legend.legend(handles_ns, labels_ns, loc='center', ncols = 2)
fig_legend.tight_layout()
if bool_for_thesis and bool_save_fig:
    main_path = Path(thesis_fig_path, f"ST_EoS_{str_Scase}_{str_Ncase}_ns.pdf")
    # fig_main.savefig(main_path, facecolor = "none", dpi = 300)
    legend_path = Path(thesis_fig_path, f"ST_EoS_legends.pdf", bbox_inches='tight')
    # fig_legend.savefig(legend_path, facecolor = "none", dpi = 300, bbox_inches='tight')
# Out:
# C:\Users\ken92\AppData\Local\Temp\ipykernel_20340\3817173227.py:3: RuntimeWarning: divide by zero encountered in log
#   S = -L * ((1 - n_f) * np.log(1 - n_f) + n_f * np.log(n_f))
# C:\Users\ken92\AppData\Local\Temp\ipykernel_20340\3817173227.py:3: RuntimeWarning: invalid value encountered in multiply
#   S = -L * ((1 - n_f) * np.log(1 - n_f) + n_f * np.log(n_f))

# %% [markdown]
# #### Full glory
# Might go into the appendix.

# %%
fig_ns_full, axes_ns_full = plt.subplots(3, 2, figsize = (7, 9))
# replaced sigma_r with n_flat
# sigma2_r_allV n_f_r_allV
# r"$\sigma_r$" r"$n_{f, r}$"
for ax, vals_allV, str_label in zip(axes_ns_full.flatten(),
        [beta_allV, mu_glob_allV, V_offset_allV, sigma2_s_allV, n_f_r_allV, varsigma_allV],
        [r"$\beta$", r"$\mu$", r"$V_{offset}$", r"$\sigma_s$", r"$n_{f, r}$", r"$\varsigma$"]):
    util.add_shades(ax, S_excess / np.max(S_excess), n_s_all, alpha = 0.5, color = "pink")
    for n_s, vals, V, i_min, idx_sgn_change in zip(n_s_allV, vals_allV, V_list, argmin_sigma2_s_allV, idx_sgn_change_allV):
        c = util.get_color(V, V_list, crange = (0.15, 0.95))
        if V == 0: c = "orange"
        # ax.plot(n_s, vals, color = c, label = f"V = {V}")
        util.plot_in_ax_break_sign_change(ax, n_s, vals, idx_sgn_change, color = c, label = f"V = {V}")
        ax.scatter(n_s[i_min], vals[i_min], color = c)
    ax.set_title(str_label)
    ax.set_xlabel(r"$n_s$")
    ax.axvline(n_s_halfnr, color = "r", ls = "--", label = r"$n_{r,f} = 1/2$")
    ax.axvline(ntot, color = "k", ls = "--", label = r"$V_{offset} = 0$")
axes_ns_full[1,0].axhline(sigma2tot, color = "grey", ls = "--", alpha = 0.5)
axes_ns_full[1,1].axhline(sigma2tot, color = "grey", ls = "--", alpha = 0.5)
# axes_ns_full.flatten()[4].legend(ncols = 2, fontsize = 'small')
fig_ns_full.suptitle(rf"$n = {ntot}$, {str_S_title} ($N_{{tot}}$ = {Ntot}, $S_{{tot}}$ = {Stot})")
fig_ns_full.tight_layout(w_pad = 0.1)
if bool_for_thesis and bool_save_fig:
    ns_full_path = Path(thesis_fig_path_app, f"ST_EoS_{str_Scase}_{str_Ncase}_ns_full.pdf")
    fig_ns_full.savefig(ns_full_path, facecolor = "none", dpi = 300, bbox_inches='tight')

# %% [markdown]
# ### as $f(V_{offset})$
# This is done by inverting $n_s$ and $V_{offset}$. Care needs to be taken when there are `np.nan` values in the arrays.
# These plot might be more natural for a fixed experiment setting.

# %%
V_plt_min = -2
if bool_for_thesis:
    if str_Ncase == "smallN":
        V_plt_min = 0
    elif str_Ncase == "bigN":
        V_plt_min = -2
V_offset_range = [V_plt_min, V_plt_min + 4]

# %%
fig_off_all_full, axes_off_all_full = plt.subplots(3, 2, figsize = (7, 9))
fig_off_lim_full, axes_off_lim_full = plt.subplots(3, 2, figsize = (7, 9))

# replaced sigma_r with n_flat
# sigma2_r_allV n_f_r_allV
# r"$\sigma_r$" r"$n_{f, r}$"
for fig, axes, V_range in zip(
    [fig_off_all_full, fig_off_lim_full],
    [axes_off_all_full, axes_off_lim_full],
    [(-100, 100), V_offset_range]
    ):
    for ax, vals_allV, str_label in zip(axes.flatten(),
            [beta_allV, mu_glob_allV, n_s_allV, sigma2_s_allV, n_f_r_allV, varsigma_allV],
            [r"$\beta$", r"$\mu$", r"$n_s$", r"$\sigma_s$", r"$n_{f, r}$", r"$\varsigma$"]):
        for V_offset, vals, V, i_min, idx_sgn_change in zip(V_offset_allV, vals_allV, V_list, argmin_sigma2_s_allV, idx_sgn_change_allV):
            c = util.get_color(V, V_list, crange = (0.15, 0.95))
            if V == 0: c = "orange"
            idx_plot = np.isnan(vals) | ((V_range[0] < V_offset) & (V_offset < V_range[1]))
            # ax.plot(V_offset[idx_plot], vals[idx_plot], label = f"V = {V}",
            #         color = c)
            util.plot_in_ax_break_sign_change(ax, V_offset[idx_plot], vals[idx_plot], idx_sgn_change[np.where(idx_sgn_change < sum(idx_plot))],
                                         label = f"V = {V}", color = c)
            if V_range[0] < V_offset[i_min] < V_range[1]: ax.scatter(V_offset[i_min], vals[i_min], color = c)
        ax.set_title(str_label)
        ax.set_xlabel(r"$V_{offset}$")
        if V_range[0] < 0. < V_range[1]: ax.axvline(0., color = "black", ls = "--")
    axes[1,0].axhline(sigma2tot, color = "grey", ls = "--", alpha = 0.5)
    axes[1,1].axhline(sigma2tot, color = "grey", ls = "--", alpha = 0.5)
    # axes.flatten()[4].legend(ncols = 2, fontsize = 'small')
    fig.suptitle(rf"$n = {ntot}$, {str_S_title} ($N_{{tot}}$ = {Ntot}, $S_{{tot}}$ = {Stot})")
    fig.tight_layout(w_pad = 0.1)

if bool_for_thesis and bool_save_fig:
    Voffset_full_path = Path(thesis_fig_path_app, f"ST_EoS_{str_Scase}_{str_Ncase}_Voffset_full.pdf")
    fig_off_lim_full.savefig(Voffset_full_path, facecolor = "none", dpi = 300, bbox_inches='tight')

# %%
fig_off_all, ax_off_all = plt.subplots(1, 1, figsize = (4, 3))   # Not gonna save this
fig_off_lim, ax_off_lim = plt.subplots(1, 1, figsize = (4, 3))

for fig, ax, V_range in zip(
    [fig_off_all, fig_off_lim],
    [ax_off_all, ax_off_lim],
    [(-100, 100), V_offset_range]
    ):
    for V_offset, vals, V, i_min, idx_sgn_change in zip(V_offset_allV, varsigma_allV, V_list, argmin_sigma2_s_allV, idx_sgn_change_allV):
        c = util.get_color(V, V_list, crange = (0.15, 0.95))
        if V == 0: c = "orange"
        idx_plot = np.isnan(vals) | ((V_range[0] < V_offset) & (V_offset < V_range[1]))
        util.plot_in_ax_break_sign_change(ax, V_offset[idx_plot], vals[idx_plot], idx_sgn_change[np.where(idx_sgn_change < sum(idx_plot))],
                                        label = f"V = {V}", color = c)
        if V_range[0] < V_offset[i_min] < V_range[1]: ax.scatter(V_offset[i_min], vals[i_min], color = c)
    ax.set_title(r"$\varsigma$", fontsize = 16)
    ax.set_xlabel(r"$V_{offset}$", fontsize = 16)
    ax.tick_params(labelsize = 12)
    if V_range[0] < 0. < V_range[1]: ax.axvline(0., color = "black", ls = "--")
    # axes.flatten()[4].legend(ncols = 2, fontsize = 'small')
    fig.tight_layout(w_pad = 0.1)

if bool_for_thesis and bool_save_fig:
    Voffset_path = Path(thesis_fig_path, f"ST_EoS_{str_Scase}_{str_Ncase}_Voffset.pdf")
    # fig_off_lim.savefig(Voffset_path, facecolor = "none", dpi = 300, bbox_inches='tight')
